# %%
# Import modules from src
import sys
sys.path.append('../src')  # Add src to path

from scraper import scrape_reviews
from preprocessor import preprocess_reviews
import pandas as pd
from tqdm import tqdm

# %%
from preprocessor import get_sentiment_scores, label_sentiment

# %%
from analyzer import SentimentAnalyzer, ThemeAnalyzer
from visualizer import ReviewVisualizer
from database import ReviewDatabase

# %%
from initialize import setup_nltk

# Run this once to download necessary resources
setup_nltk()
# Out:
# [nltk_data] Downloading package punkt to /home/age/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/age/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/age/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/age/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/age/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from preprocessor import preprocess_text

# %%
# 1. Data Collection
bank_apps = {
    'CBE': 'com.combanketh.mobilebanking',
    'BOA': 'com.boa.boaMobileBanking',
    'Dashen': 'com.dashen.dashensuperapp'
}

# %%
raw_reviews = scrape_reviews(bank_apps)
# Out:
# Scraping banks:   0%|          | 0/3 [00:00<?, ?it/s]
# Scraping banks: 100%|██████████| 3/3 [00:04<00:00,  1.54s/it]

# %%
raw_reviews.head()
# Out:
#                                reviewId                      userName  \
# 0  42eed344-f5b7-49be-a7eb-b1c14386e20b                  Tilahun Nedi
# 1  fce00cda-d71a-486e-a4c2-7479ab7793bc  Abdurahiman Abubaker Hussein
# 2  f543a13e-bc0f-4348-b57f-3a83eb67206c                 Milky Yebassa
# 3  2470d199-834a-4134-a0f9-8c684ba75491                 ENGIDA KEBEDE
# 4  4beee0dd-05ad-474c-bdff-0146723f2179                   Abel Beyena
#
#                                            userImage               content  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...             very niec
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...   best app of finance
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...              yetemeta
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...  Engida Kebede Fetera
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...                  good
#
#    score  thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0    5.0            0.0                5.1.0 2025-06-04 11:21:53         None
# 1    5.0            0.0                 None 2025-06-04 07:38:54         None
# 2    1.0            0.0                5.1.0 2025-06-03 21:04:44         None
# 3    5.0            0.0                5.1.0 2025-06-03 20:20:23         None
# 4    5.0            0.0                5.1.0 2025-06-03 11:32:52         None
#
#   repliedAt appVersion bank language
# 0      None      5.1.0  CBE       en
# 1      None       None  CBE       en
# 2      None      5.1.0  CBE       en
# 3      None      5.1.0  CBE       en
# 4      None      5.1.0  CBE       en

# %%
raw_reviews.shape
# Out:
# (1715, 13)

# %%
raw_reviews.to_csv('../datasets/raw/reviews.csv', index=False)

# %%
df = pd.read_csv('../datasets/raw/reviews.csv', parse_dates=['at'])

# %%
df.head(3)
# Out:
#                                reviewId                      userName  \
# 0  42eed344-f5b7-49be-a7eb-b1c14386e20b                  Tilahun Nedi
# 1  fce00cda-d71a-486e-a4c2-7479ab7793bc  Abdurahiman Abubaker Hussein
# 2  f543a13e-bc0f-4348-b57f-3a83eb67206c                 Milky Yebassa
#
#                                            userImage              content  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...            very niec
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...  best app of finance
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...             yetemeta
#
#    score  thumbsUpCount reviewCreatedVersion                  at  \
# 0    5.0            0.0                5.1.0 2025-06-04 11:21:53
# 1    5.0            0.0                  NaN 2025-06-04 07:38:54
# 2    1.0            0.0                5.1.0 2025-06-03 21:04:44
#
#    replyContent  repliedAt appVersion bank language
# 0           NaN        NaN      5.1.0  CBE       en
# 1           NaN        NaN        NaN  CBE       en
# 2           NaN        NaN      5.1.0  CBE       en

# %%
# preprocess_text(df['content'], language='en')

# %%
# 2. Data Preprocessing
cleaned_df = preprocess_reviews(df)
cleaned_df.to_csv('../datasets/raw/cleaned_reviews.csv', index=False)
# Out:
# Preprocessing text: 100%|██████████| 1437/1437 [00:01<00:00, 1400.34it/s]

# %%
cleaned_df
# Out:
#                                                  review  rating        date  \
# 0                                             very niec     5.0  2025-06-04
# 1                                   best app of finance     5.0  2025-06-04
# 2                                              yetemeta     1.0  2025-06-03
# 3                                  Engida Kebede Fetera     5.0  2025-06-03
# 4                                                  good     5.0  2025-06-03
# ...                                                 ...     ...         ...
# 1709                            Faster and userfriendly     5.0  2025-01-14
# 1711  Waw Great and innovated,user friendly, always ...     5.0  2025-01-13
# 1712                                   It's Best waww 🙏     5.0  2025-01-13
# 1713                              Always one step ahead     5.0  2025-01-13
# 1714       Like Me, I Hope It Works Better Than Before.     5.0  2025-01-11
#
#         bank language                                   processed_review
# 0        CBE       en                                               niec
# 1        CBE       en                                   best app finance
# 2        CBE       en                                           yetemeta
# 3        CBE       en                               engida kebede fetera
# 4        CBE       en                                               good
# ...      ...      ...                                                ...
# 1709  Dashen       en                                faster userfriendly
# 1711  Dashen       en  waw great innovateduser friendly always one st...
# 1712  Dashen       en                                          best waww
# 1713  Dashen       en                              always one step ahead
# 1714  Dashen       en                             like hope works better
#
# [1437 rows x 6 columns]

# %%
cleaned_df = get_sentiment_scores(cleaned_df)
# Out:
# Calculating sentiment scores: 100%|██████████| 1437/1437 [00:00<00:00, 11039.10it/s]

# %%
cleaned_df
# Out:
#                                                  review  rating        date  \
# 0                                             very niec     5.0  2025-06-04
# 1                                   best app of finance     5.0  2025-06-04
# 2                                              yetemeta     1.0  2025-06-03
# 3                                  Engida Kebede Fetera     5.0  2025-06-03
# 4                                                  good     5.0  2025-06-03
# ...                                                 ...     ...         ...
# 1709                            Faster and userfriendly     5.0  2025-01-14
# 1711  Waw Great and innovated,user friendly, always ...     5.0  2025-01-13
# 1712                                   It's Best waww 🙏     5.0  2025-01-13
# 1713                              Always one step ahead     5.0  2025-01-13
# 1714       Like Me, I Hope It Works Better Than Before.     5.0  2025-01-11
#
#         bank language                                   processed_review  \
# 0        CBE       en                                               niec
# 1        CBE       en                                   best app finance
# 2        CBE       en                                           yetemeta
# 3        CBE       en                               engida kebede fetera
# 4        CBE       en                                               good
# ...      ...      ...                                                ...
# 1709  Dashen       en                                faster userfriendly
# 1711  Dashen       en  waw great innovateduser friendly always one st...
# 1712  Dashen       en                                          best waww
# 1713  Dashen       en                              always one step ahead
# 1714  Dashen       en                             like hope works better
#
#       sentiment
# 0        0.0000
# 1        0.6369
# 2        0.0000
# 3        0.0000
# 4        0.4404
# ...         ...
# 1709     0.0000
# 1711     0.8074
# 1712     0.6369
# 1713     0.0000
# 1714     0.8074
#
# [1437 rows x 7 columns]

# %%
cleaned_df = label_sentiment(cleaned_df)

# %%
cleaned_df
# Out:
#                                                  review  rating        date  \
# 0                                             very niec     5.0  2025-06-04
# 1                                   best app of finance     5.0  2025-06-04
# 2                                              yetemeta     1.0  2025-06-03
# 3                                  Engida Kebede Fetera     5.0  2025-06-03
# 4                                                  good     5.0  2025-06-03
# ...                                                 ...     ...         ...
# 1709                            Faster and userfriendly     5.0  2025-01-14
# 1711  Waw Great and innovated,user friendly, always ...     5.0  2025-01-13
# 1712                                   It's Best waww 🙏     5.0  2025-01-13
# 1713                              Always one step ahead     5.0  2025-01-13
# 1714       Like Me, I Hope It Works Better Than Before.     5.0  2025-01-11
#
#         bank language                                   processed_review  \
# 0        CBE       en                                               niec
# 1        CBE       en                                   best app finance
# 2        CBE       en                                           yetemeta
# 3        CBE       en                               engida kebede fetera
# 4        CBE       en                                               good
# ...      ...      ...                                                ...
# 1709  Dashen       en                                faster userfriendly
# 1711  Dashen       en  waw great innovateduser friendly always one st...
# 1712  Dashen       en                                          best waww
# 1713  Dashen       en                              always one step ahead
# 1714  Dashen       en                             like hope works better
#
#       sentiment     label
# 0        0.0000   neutral
# 1        0.6369  positive
# 2        0.0000   neutral
# 3        0.0000   neutral
# 4        0.4404  positive
# ...         ...       ...
# 1709     0.0000   neutral
# 1711     0.8074  positive
# 1712     0.6369  positive
# 1713     0.0000   neutral
# 1714     0.8074  positive
#
# [1437 rows x 8 columns]

# %%
average_sentiment = cleaned_df['sentiment'].mean()
max_sentiment = cleaned_df['sentiment'].max()
min_sentiment = cleaned_df['sentiment'].min()
print(f'Max Sentiment Score: {max_sentiment:.2f}')
print(f'Min Sentiment Score: {min_sentiment:.2f}')
print(f'Average Sentiment Score: {average_sentiment:.2f}')
# Out:
# Max Sentiment Score: 0.98
# Min Sentiment Score: -0.96
# Average Sentiment Score: 0.25
